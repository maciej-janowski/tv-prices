# %%
# importing necessary libraries
import os
import pandas as pd
from bs4 import BeautifulSoup
import re
from sqlalchemy import create_engine

# creatin empty dictionary for storing data for tv sets
list_of_tvs = {}

# declaring folder with downloaded pages
pages_folder = input("Full path to folder with pages")
# looping over all files in folder (downloaded pages)
for filename in os.listdir(f'{pages_folder}\\'):

    # checking the extension of the file
    if '.htm' in filename:

        # assigning path to file
        file_path = f'{pages_folder}\\{filename}'

        # opening file
        with open(file_path,'rb') as fp:

            # creating bs object
            soup = BeautifulSoup(fp.read())

            # finding the table with details
            data_table = soup.find('table',class_='description-tech-details')

            # assigning dictionary for features of the tv set
            features = {}

            # finding price
            price = soup.find('div',class_='product-price selenium-price-normal')

            # assigninig price (it is placed outside table with details regarding product)
            features['Price'] = int(re.match('\d+',price.text.strip().replace(u'\xa0', u'')).group(0))

            # looping over all rows
            for tag in data_table.find_all('tr'):

                # if row is with class (only those are showing some features of the product)
                if 'class' not in tag.attrs.keys():

                    # extracting data from row
                    tds = tag.find_all('td')

                    # assigning feature name to the value of this feature
                    features[tds[0].text.strip()] = tds[1].text.strip()
                    
            # finding the name of the tv set and assigning it to all features found on the page
            list_of_tvs[re.search('(.+)_HEVC',filename).group(0)] = features

# %%
df = pd.DataFrame.from_dict(list_of_tvs, orient='index')
df.to_csv('raw_tv_sets.csv')

# %%
# df = pd.read_csv('raw_tv_sets.csv',index_col=0)

# %%
# extracting size of tv_set
df['size in inches'] = df['Rozmiar ekranu'].str.extract(r'(\d\d)')[0]

# %%
# getting the resolution (Full HD, HD Ready, 4 UHD)
df['Resolution'] = df['Format HD / Rozdzielczość'].str.extract(r'(.+\s?\w+)\s/')

# %%
# checking if Direct LED technology is present
df['Direct LED'] = df['Podświetlenie matrycy'].str.contains("Direct LED").astype(int)

# %%
# checking number of tuners
df['Tuners number'] = df['Tuner'].str.split(',').str.len()

# %%
# checking if HD double tuner is present
df['Double Tuner'] = df['Podwójny tuner HD'].replace({'nie':False,"tak":True}).astype(int)

# %%
# checking if system is running on Android 10
df['Android 10'] = df['System Smart'].str.contains('Android 10').fillna(False).astype(int)

# %%
# checking if Wi-Fi Direct is present
df['Wi-Fi Direct'] = df['Łączność bezprzewodowa'].str.contains("Wi-Fi Direct").fillna(False).astype(int)

# %%
# checking how many assitants are available
df['Number_Of_Available_Assistants'] = df['Kompatybilność z asystentem głosowym'].str.split(',').str.len().fillna(0).astype(int)

# %%
# function for extracting and calculating the speakers' power from all installed
def sound_power(speakers_list):
    power = 0
    for s_et in speakers_list:
        if 'x' in s_et:
            power += int(s_et[0]) *int(re.match('(\d?)\sx\s(\d+)',s_et).group(2))
        else:
            power += int(re.match('(\d+)',s_et).group(0))
    return power

# %%
# extracting speakers' power
df['Total_speakers_power'] = df['System i moc głośników'].str.extract('/ (.+)')[0].str.split('+').apply(lambda x: [speaker.strip() for speaker in x]).apply(sound_power)

# %%
# checking number of HDMI slots 
df['HDMI slots number'] = df['Liczba złączy HDMI'].str[0].astype(int)

# %%
# checking if HDMI 2.1 is present
df['HDMI 2.1 slots'] = df['Liczba złączy HDMI'].str.contains('2.1').astype(int)

# %%
# assigning energy consumption class
df['Energy consumption class'] = df['Klasa energetyczna SDR']

# %%
# checking if remote controller has microphone
df['Remote controller with mic'] = df['Wyposażenie'].str.contains('mikrofonem').astype(int)

# %%
# assigning power maximum power consumption. If data was not available - mean power consumption of all products were set
df['Power consumption'] = df['Pobór mocy (max)'].str.extract('(\d+)').astype(float).pipe(lambda df:df.fillna(df[0].mean()))[0]

# %%
# selecting necessary columns
list_of_columns = ['Price','Resolution','Direct LED','Tuners number','Double Tuner','Android 10','Wi-Fi Direct','Number_Of_Available_Assistants','Total_speakers_power',
'HDMI slots number','HDMI 2.1 slots','Remote controller with mic','Power consumption','Energy consumption class']

# %%
# filtering dataframe so that it has only selected columns and dumping to excel
df[list_of_columns].to_csv('transformed_tv_sets.csv')

# %%
# creating dataframe with selected columns
final_df = df[list_of_columns]

# %%
# adjusting the naming of columns so that names fit column headers in database
final_df.columns = final_df.rename(columns={"HDMI 2.1 slots":"HDMI_two_point_one_slots"}).columns.str.replace(' ',"_")
final_df.columns = final_df.columns.str.replace("-","_")
final_df.columns = final_df.columns.str.lower()

# %%
# final dataframe after adjustments
final_df
# Out:
#                                                     price resolution  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                 1699     4K UHD
# Telewizor LG 55NANO753PR DVB-T2_HEVC                 2299     4K UHD
# Telewizor LG 65NANO863PA DVB-T2_HEVC                 3299     4K UHD
# Telewizor LG OLED55C11LB DVB-T2_HEVC                 4699     4K UHD
# Telewizor Lin 32D1700 DVB-T2_HEVC                     719   HD Ready
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                   615   HD Ready
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC          3499     4K UHD
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC           3299     4K UHD
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC           5499     4K UHD
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC        2999     4K UHD
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...   3190     4K UHD
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC            1839     4K UHD
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC            1499     4K UHD
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                  1549     4K UHD
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                  1699     4K UHD
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                  2999     4K UHD
# Telewizor Sony KD-65X89J DVB-T2_HEVC                 4699     4K UHD
# Telewizor Sony XR-55X90J DVB-T2_HEVC                 4499     4K UHD
# Telewizor Sony XR-65X90J DVB-T2_HEVC                 5299     4K UHD
# Telewizor TCL 40S615 DVB-T2_HEVC                     1299    Full HD
# Telewizor TCL 43P615 DVB-T2_HEVC                     1599     4K UHD
# Telewizor TCL 50P610 DVB-T2_HEVC                     1799     4K UHD
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...   1799     4K UHD
#
#                                                     direct_led  tuners_number  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                         1              6
# Telewizor LG 55NANO753PR DVB-T2_HEVC                         1              6
# Telewizor LG 65NANO863PA DVB-T2_HEVC                         0              6
# Telewizor LG OLED55C11LB DVB-T2_HEVC                         0              5
# Telewizor Lin 32D1700 DVB-T2_HEVC                            1              4
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                          1              4
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                  0              5
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                   1              6
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                   1              6
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                0              4
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...           0              4
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                    0              3
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                    0              3
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                          1              6
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                          1              6
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                          1              6
# Telewizor Sony KD-65X89J DVB-T2_HEVC                         1              6
# Telewizor Sony XR-55X90J DVB-T2_HEVC                         1              6
# Telewizor Sony XR-65X90J DVB-T2_HEVC                         1              6
# Telewizor TCL 40S615 DVB-T2_HEVC                             1              4
# Telewizor TCL 43P615 DVB-T2_HEVC                             1              4
# Telewizor TCL 50P610 DVB-T2_HEVC                             1              4
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...           1              3
#
#                                                     double_tuner  android_10  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                           0           0
# Telewizor LG 55NANO753PR DVB-T2_HEVC                           0           0
# Telewizor LG 65NANO863PA DVB-T2_HEVC                           0           0
# Telewizor LG OLED55C11LB DVB-T2_HEVC                           0           0
# Telewizor Lin 32D1700 DVB-T2_HEVC                              0           0
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                            0           0
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                    1           0
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                     0           0
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                     0           1
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                  1           0
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...             0           0
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                      0           0
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                      0           0
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                            0           0
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                            0           0
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                            0           0
# Telewizor Sony KD-65X89J DVB-T2_HEVC                           0           1
# Telewizor Sony XR-55X90J DVB-T2_HEVC                           1           1
# Telewizor Sony XR-65X90J DVB-T2_HEVC                           1           1
# Telewizor TCL 40S615 DVB-T2_HEVC                               0           0
# Telewizor TCL 43P615 DVB-T2_HEVC                               0           0
# Telewizor TCL 50P610 DVB-T2_HEVC                               0           0
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...             0           1
#
#                                                     wi_fi_direct  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                           0
# Telewizor LG 55NANO753PR DVB-T2_HEVC                           0
# Telewizor LG 65NANO863PA DVB-T2_HEVC                           0
# Telewizor LG OLED55C11LB DVB-T2_HEVC                           0
# Telewizor Lin 32D1700 DVB-T2_HEVC                              0
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                            0
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                    0
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                     0
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                     0
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                  1
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...             1
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                      1
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                      1
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                            0
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                            0
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                            0
# Telewizor Sony KD-65X89J DVB-T2_HEVC                           0
# Telewizor Sony XR-55X90J DVB-T2_HEVC                           0
# Telewizor Sony XR-65X90J DVB-T2_HEVC                           0
# Telewizor TCL 40S615 DVB-T2_HEVC                               0
# Telewizor TCL 43P615 DVB-T2_HEVC                               0
# Telewizor TCL 50P610 DVB-T2_HEVC                               0
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...             1
#
#                                                     number_of_available_assistants  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                                             2
# Telewizor LG 55NANO753PR DVB-T2_HEVC                                             2
# Telewizor LG 65NANO863PA DVB-T2_HEVC                                             2
# Telewizor LG OLED55C11LB DVB-T2_HEVC                                             2
# Telewizor Lin 32D1700 DVB-T2_HEVC                                                0
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                                              0
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                                      2
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                                       2
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                                       2
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                                    1
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...                               3
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                                        0
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                                        0
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                                              1
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                                              1
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                                              1
# Telewizor Sony KD-65X89J DVB-T2_HEVC                                             1
# Telewizor Sony XR-55X90J DVB-T2_HEVC                                             1
# Telewizor Sony XR-65X90J DVB-T2_HEVC                                             1
# Telewizor TCL 40S615 DVB-T2_HEVC                                                 1
# Telewizor TCL 43P615 DVB-T2_HEVC                                                 2
# Telewizor TCL 50P610 DVB-T2_HEVC                                                 1
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...                               1
#
#                                                     total_speakers_power  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                                  20
# Telewizor LG 55NANO753PR DVB-T2_HEVC                                  20
# Telewizor LG 65NANO863PA DVB-T2_HEVC                                  20
# Telewizor LG OLED55C11LB DVB-T2_HEVC                                  40
# Telewizor Lin 32D1700 DVB-T2_HEVC                                     10
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                                   10
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                           20
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                            20
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                            50
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                         20
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...                    40
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                             20
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                             20
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                                   20
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                                   20
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                                   35
# Telewizor Sony KD-65X89J DVB-T2_HEVC                                  20
# Telewizor Sony XR-55X90J DVB-T2_HEVC                                  20
# Telewizor Sony XR-65X90J DVB-T2_HEVC                                  20
# Telewizor TCL 40S615 DVB-T2_HEVC                                      10
# Telewizor TCL 43P615 DVB-T2_HEVC                                      16
# Telewizor TCL 50P610 DVB-T2_HEVC                                      16
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...                    20
#
#                                                     hdmi_slots_number  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                                2
# Telewizor LG 55NANO753PR DVB-T2_HEVC                                3
# Telewizor LG 65NANO863PA DVB-T2_HEVC                                4
# Telewizor LG OLED55C11LB DVB-T2_HEVC                                4
# Telewizor Lin 32D1700 DVB-T2_HEVC                                   2
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                                 2
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                         4
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                          4
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                          4
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                       4
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...                  4
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                           3
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                           2
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                                 3
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                                 4
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                                 4
# Telewizor Sony KD-65X89J DVB-T2_HEVC                                4
# Telewizor Sony XR-55X90J DVB-T2_HEVC                                4
# Telewizor Sony XR-65X90J DVB-T2_HEVC                                4
# Telewizor TCL 40S615 DVB-T2_HEVC                                    2
# Telewizor TCL 43P615 DVB-T2_HEVC                                    2
# Telewizor TCL 50P610 DVB-T2_HEVC                                    3
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...                  3
#
#                                                     hdmi_two_point_one_slots  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                                       0
# Telewizor LG 55NANO753PR DVB-T2_HEVC                                       0
# Telewizor LG 65NANO863PA DVB-T2_HEVC                                       1
# Telewizor LG OLED55C11LB DVB-T2_HEVC                                       1
# Telewizor Lin 32D1700 DVB-T2_HEVC                                          0
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                                        0
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                                1
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                                 0
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                                 1
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                              1
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...                         1
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                                  0
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                                  0
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                                        0
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                                        0
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                                        0
# Telewizor Sony KD-65X89J DVB-T2_HEVC                                       1
# Telewizor Sony XR-55X90J DVB-T2_HEVC                                       1
# Telewizor Sony XR-65X90J DVB-T2_HEVC                                       1
# Telewizor TCL 40S615 DVB-T2_HEVC                                           0
# Telewizor TCL 43P615 DVB-T2_HEVC                                           0
# Telewizor TCL 50P610 DVB-T2_HEVC                                           0
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...                         0
#
#                                                     remote_controller_with_mic  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                                         0
# Telewizor LG 55NANO753PR DVB-T2_HEVC                                         0
# Telewizor LG 65NANO863PA DVB-T2_HEVC                                         0
# Telewizor LG OLED55C11LB DVB-T2_HEVC                                         0
# Telewizor Lin 32D1700 DVB-T2_HEVC                                            0
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                                          0
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                                  1
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                                   1
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                                   1
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                                0
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...                           0
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                                    0
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                                    0
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                                          1
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                                          1
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                                          1
# Telewizor Sony KD-65X89J DVB-T2_HEVC                                         1
# Telewizor Sony XR-55X90J DVB-T2_HEVC                                         1
# Telewizor Sony XR-65X90J DVB-T2_HEVC                                         1
# Telewizor TCL 40S615 DVB-T2_HEVC                                             0
# Telewizor TCL 43P615 DVB-T2_HEVC                                             0
# Telewizor TCL 50P610 DVB-T2_HEVC                                             0
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...                           1
#
#                                                     power_consumption  \
# Telewizor LG 50UP75003LF DVB-T2_HEVC                       160.333333
# Telewizor LG 55NANO753PR DVB-T2_HEVC                       160.333333
# Telewizor LG 65NANO863PA DVB-T2_HEVC                       160.333333
# Telewizor LG OLED55C11LB DVB-T2_HEVC                       160.333333
# Telewizor Lin 32D1700 DVB-T2_HEVC                          160.333333
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                        160.333333
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                241.000000
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                 160.333333
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                 160.333333
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC              205.000000
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...         170.000000
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                  160.333333
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                  125.000000
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                        115.000000
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                        115.000000
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                        245.000000
# Telewizor Sony KD-65X89J DVB-T2_HEVC                       263.000000
# Telewizor Sony XR-55X90J DVB-T2_HEVC                       160.333333
# Telewizor Sony XR-65X90J DVB-T2_HEVC                       160.333333
# Telewizor TCL 40S615 DVB-T2_HEVC                           100.000000
# Telewizor TCL 43P615 DVB-T2_HEVC                           110.000000
# Telewizor TCL 50P610 DVB-T2_HEVC                           130.000000
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...         105.000000
#
#                                                    energy_consumption_class
# Telewizor LG 50UP75003LF DVB-T2_HEVC                                      G
# Telewizor LG 55NANO753PR DVB-T2_HEVC                                      G
# Telewizor LG 65NANO863PA DVB-T2_HEVC                                      F
# Telewizor LG OLED55C11LB DVB-T2_HEVC                                      G
# Telewizor Lin 32D1700 DVB-T2_HEVC                                         F
# Telewizor Lin 32LHD1510 DVB-T2_HEVC                                       F
# Telewizor Panasonic TX-55JX940E DVB-T2_HEVC                               G
# Telewizor Philips 58PUS8506_12 DVB-T2_HEVC                                G
# Telewizor Philips 65PUS9206_12 DVB-T2_HEVC                                F
# Telewizor Samsung QLED QE55Q77AAT DVB-T2_HEVC                             F
# Telewizor Samsung The Frame QE55LS03AAU QLED TV...                        G
# Telewizor Samsung UE43AU8002K DVB-T2_HEVC                                 G
# Telewizor Samsung UE43TU7022K DVB-T2_HEVC                                 G
# Telewizor Sharp 43BL5EA DVB-T2_HEVC                                       G
# Telewizor Sharp 50DL3EA DVB-T2_HEVC                                       G
# Telewizor Sharp 70CL5EA DVB-T2_HEVC                                       G
# Telewizor Sony KD-65X89J DVB-T2_HEVC                                      G
# Telewizor Sony XR-55X90J DVB-T2_HEVC                                      G
# Telewizor Sony XR-65X90J DVB-T2_HEVC                                      G
# Telewizor TCL 40S615 DVB-T2_HEVC                                          E
# Telewizor TCL 43P615 DVB-T2_HEVC                                          E
# Telewizor TCL 50P610 DVB-T2_HEVC                                          F
# Telewizor Xiaomi Mi LED TV P1 43' (L43M6-6AEU) ...                        G

# %%
# creating engine for database connection and saving created dataframe to database (POSTGRES)
engine = create_engine(f"postgresql+psycopg2://{os.environ.get('DB_USER')}:{os.environ.get('DB_PASSWORD')}@localhost:5432/ORG")
final_df.to_sql('tv_sets',engine,if_exists='append',index=False)
